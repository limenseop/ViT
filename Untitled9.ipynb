# %% [markdown]
# <a href="https://colab.research.google.com/github/limenseop/ViT/blob/ViT_code/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 492.6 kB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.7.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

from torch import optim
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os
from torchvision import utils


from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary
import numpy as np
import time
import copy
import random
from tqdm.notebook import tqdm
import math

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# specify path to data
path2data = '/content/data'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor())
val_ds = datasets.STL10(path2data, split='test', download=True, transform=transforms.ToTensor())

print(len(train_ds))
print(len(val_ds))
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to /content/data/stl10_binary.tar.gz
# 100%|██████████| 2640397119/2640397119 [04:09<00:00, 10575949.87it/s]
# Extracting /content/data/stl10_binary.tar.gz to /content/data
# Files already downloaded and verified
# 5000
# 8000

# %%
# define transformation
transformation = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224)
])

# apply transformation to dataset
train_ds.transform = transformation
val_ds.transform = transformation

# make dataloade
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=64, shuffle=True)

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_channels=3, patch_size=16, emb_size=768, img_size=224):
        super().__init__()
        self.patch_size = patch_size

        # # Method 1: Flatten and FC layer
        # self.projection = nn.Sequential(
        #     Rearrange('b c (h s1) (w s2) -> b (h w) (s1 s2 c)', s1=patch_size, s2=patch_size),
        #     nn.Linear(path_size * patch_size * in_channels, emb_size)
        # )

        # Method 2: Conv
        self.projection = nn.Sequential(
            # using a conv layer instead of a linear one -> performance gains
            nn.Conv2d(in_channels, emb_size, patch_size, stride=patch_size),
            Rearrange('b e (h) (w) -> b (h w) e')
        )

        self.cls_token = nn.Parameter(torch.randn(1,1,emb_size))
        self.positions = nn.Parameter(torch.randn((img_size // patch_size) ** 2 + 1, emb_size))

    def forward(self, x):
        b = x.shape[0]
        x = self.projection(x)
        cls_tokens = repeat(self.cls_token, '() n e -> b n e', b=b)
        # prepend the cls token to the input
        x = torch.cat([cls_tokens, x], dim=1)
        # add position embedding to prejected patches
        x += self.positions
        return x

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size=768, num_heads=8, dropout=0):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        self.keys = nn.Linear(emb_size, emb_size)
        self.queries = nn.Linear(emb_size, emb_size)
        self.values = nn.Linear(emb_size, emb_size)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)

    def forward(self, x, mask=None):
        # split keys, queries and values in num_heads
        queries = rearrange(self.queries(x), 'b n (h d) -> b h n d', h=self.num_heads) # b, 197, 728 -> b, 8, 197, 91
        keys = rearrange(self.keys(x), 'b n (h d) -> b h n d', h=self.num_heads)
        values = rearrange(self.values(x), 'b n (h d) -> b h n d', h=self.num_heads)
        # sum up over the last axis, b,h,197,197
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys) # batch, num_head, query_len, key_len

        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)

        scaling = self.emb_size ** (1/2)
        att = F.softmax(energy, dim=-1) / scaling
        att = self.att_drop(att)
        # sum up over the third axis
        out = torch.einsum('bhal, bhlv -> bhav', att, values) # 197x91
        out = rearrange(out, 'b h n d -> b n (h d)')
        out = self.projection(out)
        return out

# %%
class ResidualAdd(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, **kwargs):
        res = x
        x = self.fn(x, **kwargs)
        x += res
        return x

# %%
class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size, expansion=4, drop_p=0.):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )

# %%
class TransformerEncoderBlock(nn.Sequential):
    def __init__(self, emb_size=768, drop_p=0., forward_expansion=4, forward_drop_p=0., **kwargs):
        super().__init__(
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                MultiHeadAttention(emb_size, **kwargs),
                nn.Dropout(drop_p)
            )),
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                FeedForwardBlock(emb_size, expansion=forward_expansion, drop_p=forward_drop_p),
                nn.Dropout(drop_p)
            ))
        )

# %%
class TransformerEncoder(nn.Sequential):
    def __init__(self, depth=12, **kwargs):
        super().__init__(*[TransformerEncoderBlock(**kwargs) for _ in range(depth)])

# %%
class ClassificationHead(nn.Sequential):
    def __init__(self, emb_size=768, n_classes = 10):
        super().__init__(
            Reduce('b n e -> b e', reduction='mean'),
            nn.LayerNorm(emb_size),
            nn.Linear(emb_size, n_classes))

# %%
class ViT(nn.Sequential):
    def __init__(self, in_channels=3, patch_size=16, emb_size=768, img_size=224, depth=12, n_classes=10, **kwargs):
        super().__init__(
            PatchEmbedding(in_channels, patch_size, emb_size, img_size),
            TransformerEncoder(depth, emb_size=emb_size, **kwargs),
            ClassificationHead(emb_size, n_classes)
        )

# %%
model = ViT().to(device)
summary(model, (3,224,224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 768, 14, 14]         590,592
#          Rearrange-2             [-1, 196, 768]               0
#     PatchEmbedding-3             [-1, 197, 768]               0
#          LayerNorm-4             [-1, 197, 768]           1,536
#             Linear-5             [-1, 197, 768]         590,592
#             Linear-6             [-1, 197, 768]         590,592
#             Linear-7             [-1, 197, 768]         590,592
#            Dropout-8          [-1, 8, 197, 197]               0
#             Linear-9             [-1, 197, 768]         590,592
# MultiHeadAttention-10             [-1, 197, 768]               0
#           Dropout-11             [-1, 197, 768]               0
#       ResidualAdd-12             [-1, 197, 768]               0
#         LayerNorm-13             [-1, 197, 768]           1,536
#            Linear-14            [-1, 197, 3072]       2,362,368
#              GELU-15            [-1, 197, 3072]               0
#           Dropout-16            [-1, 197, 3072]               0
#            Linear-17             [-1, 197, 768]       2,360,064
#           Dropout-18             [-1, 197, 768]               0
#       ResidualAdd-19             [-1, 197, 768]               0
#         LayerNorm-20             [-1, 197, 768]           1,536
#            Linear-21             [-1, 197, 768]         590,592
#            Linear-22             [-1, 197, 768]         590,592
#            Linear-23             [-1, 197, 768]         590,592
#           Dropout-24          [-1, 8, 197, 197]               0
#            Linear-25             [-1, 197, 768]         590,592
# MultiHeadAttention-26             [-1, 197, 768]               0
#           Dropout-27             [-1, 197, 768]               0
#       ResidualAdd-28             [-1, 197, 768]               0
#         LayerNorm-29             [-1, 197, 768]           1,536
#            Linear-30            [-1, 197, 3072]       2,362,368
#              GELU-31            [-1, 197, 3072]               0
#           Dropout-32            [-1, 197, 3072]               0
#            Linear-33             [-1, 197, 768]       2,360,064
#           Dropout-34             [-1, 197, 768]               0
#       ResidualAdd-35             [-1, 197, 768]               0
#         LayerNorm-36             [-1, 197, 768]           1,536
#            Linear-37             [-1, 197, 768]         590,592
#            Linear-38             [-1, 197, 768]         590,592
#            Linear-39             [-1, 197, 768]         590,592
#           Dropout-40          [-1, 8, 197, 197]               0
#            Linear-41             [-1, 197, 768]         590,592
# MultiHeadAttention-42             [-1, 197, 768]               0
#           Dropout-43             [-1, 197, 768]               0
#       ResidualAdd-44             [-1, 197, 768]               0
#         LayerNorm-45             [-1, 197, 768]           1,536
#            Linear-46            [-1, 197, 3072]       2,362,368
#              GELU-47            [-1, 197, 3072]               0
#           Dropout-48            [-1, 197, 3072]               0
#            Linear-49             [-1, 197, 768]       2,360,064
#           Dropout-50             [-1, 197, 768]               0
#       ResidualAdd-51             [-1, 197, 768]               0
#         LayerNorm-52             [-1, 197, 768]           1,536
#            Linear-53             [-1, 197, 768]         590,592
#            Linear-54             [-1, 197, 768]         590,592
#            Linear-55             [-1, 197, 768]         590,592
#           Dropout-56          [-1, 8, 197, 197]               0
#            Linear-57             [-1, 197, 768]         590,592
# MultiHeadAttention-58             [-1, 197, 768]               0
#           Dropout-59             [-1, 197, 768]               0
#       ResidualAdd-60             [-1, 197, 768]               0
#         LayerNorm-61             [-1, 197, 768]           1,536
#            Linear-62            [-1, 197, 3072]       2,362,368
#              GELU-63            [-1, 197, 3072]               0
#           Dropout-64            [-1, 197, 3072]               0
#            Linear-65             [-1, 197, 768]       2,360,064
#           Dropout-66             [-1, 197, 768]               0
#       ResidualAdd-67             [-1, 197, 768]               0
#         LayerNorm-68             [-1, 197, 768]           1,536
#            Linear-69             [-1, 197, 768]         590,592
#            Linear-70             [-1, 197, 768]         590,592
#            Linear-71             [-1, 197, 768]         590,592
#           Dropout-72          [-1, 8, 197, 197]               0
#            Linear-73             [-1, 197, 768]         590,592
# MultiHeadAttention-74             [-1, 197, 768]               0
#           Dropout-75             [-1, 197, 768]               0
#       ResidualAdd-76             [-1, 197, 768]               0
#         LayerNorm-77             [-1, 197, 768]           1,536
#            Linear-78            [-1, 197, 3072]       2,362,368
#              GELU-79            [-1, 197, 3072]               0
#           Dropout-80            [-1, 197, 3072]               0
#            Linear-81             [-1, 197, 768]       2,360,064
#           Dropout-82             [-1, 197, 768]               0
#       ResidualAdd-83             [-1, 197, 768]               0
#         LayerNorm-84             [-1, 197, 768]           1,536
#            Linear-85             [-1, 197, 768]         590,592
#            Linear-86             [-1, 197, 768]         590,592
#            Linear-87             [-1, 197, 768]         590,592
#           Dropout-88          [-1, 8, 197, 197]               0
#            Linear-89             [-1, 197, 768]         590,592
# MultiHeadAttention-90             [-1, 197, 768]               0
#           Dropout-91             [-1, 197, 768]               0
#       ResidualAdd-92             [-1, 197, 768]               0
#         LayerNorm-93             [-1, 197, 768]           1,536
#            Linear-94            [-1, 197, 3072]       2,362,368
#              GELU-95            [-1, 197, 3072]               0
#           Dropout-96            [-1, 197, 3072]               0
#            Linear-97             [-1, 197, 768]       2,360,064
#           Dropout-98             [-1, 197, 768]               0
#       ResidualAdd-99             [-1, 197, 768]               0
#        LayerNorm-100             [-1, 197, 768]           1,536
#           Linear-101             [-1, 197, 768]         590,592
#           Linear-102             [-1, 197, 768]         590,592
#           Linear-103             [-1, 197, 768]         590,592
#          Dropout-104          [-1, 8, 197, 197]               0
#           Linear-105             [-1, 197, 768]         590,592
# MultiHeadAttention-106             [-1, 197, 768]               0
#          Dropout-107             [-1, 197, 768]               0
#      ResidualAdd-108             [-1, 197, 768]               0
#        LayerNorm-109             [-1, 197, 768]           1,536
#           Linear-110            [-1, 197, 3072]       2,362,368
#             GELU-111            [-1, 197, 3072]               0
#          Dropout-112            [-1, 197, 3072]               0
#           Linear-113             [-1, 197, 768]       2,360,064
#          Dropout-114             [-1, 197, 768]               0
#      ResidualAdd-115             [-1, 197, 768]               0
#        LayerNorm-116             [-1, 197, 768]           1,536
#           Linear-117             [-1, 197, 768]         590,592
#           Linear-118             [-1, 197, 768]         590,592
#           Linear-119             [-1, 197, 768]         590,592
#          Dropout-120          [-1, 8, 197, 197]               0
#           Linear-121             [-1, 197, 768]         590,592
# MultiHeadAttention-122             [-1, 197, 768]               0
#          Dropout-123             [-1, 197, 768]               0
#      ResidualAdd-124             [-1, 197, 768]               0
#        LayerNorm-125             [-1, 197, 768]           1,536
#           Linear-126            [-1, 197, 3072]       2,362,368
#             GELU-127            [-1, 197, 3072]               0
#          Dropout-128            [-1, 197, 3072]               0
#           Linear-129             [-1, 197, 768]       2,360,064
#          Dropout-130             [-1, 197, 768]               0
#      ResidualAdd-131             [-1, 197, 768]               0
#        LayerNorm-132             [-1, 197, 768]           1,536
#           Linear-133             [-1, 197, 768]         590,592
#           Linear-134             [-1, 197, 768]         590,592
#           Linear-135             [-1, 197, 768]         590,592
#          Dropout-136          [-1, 8, 197, 197]               0
#           Linear-137             [-1, 197, 768]         590,592
# MultiHeadAttention-138             [-1, 197, 768]               0
#          Dropout-139             [-1, 197, 768]               0
#      ResidualAdd-140             [-1, 197, 768]               0
#        LayerNorm-141             [-1, 197, 768]           1,536
#           Linear-142            [-1, 197, 3072]       2,362,368
#             GELU-143            [-1, 197, 3072]               0
#          Dropout-144            [-1, 197, 3072]               0
#           Linear-145             [-1, 197, 768]       2,360,064
#          Dropout-146             [-1, 197, 768]               0
#      ResidualAdd-147             [-1, 197, 768]               0
#        LayerNorm-148             [-1, 197, 768]           1,536
#           Linear-149             [-1, 197, 768]         590,592
#           Linear-150             [-1, 197, 768]         590,592
#           Linear-151             [-1, 197, 768]         590,592
#          Dropout-152          [-1, 8, 197, 197]               0
#           Linear-153             [-1, 197, 768]         590,592
# MultiHeadAttention-154             [-1, 197, 768]               0
#          Dropout-155             [-1, 197, 768]               0
#      ResidualAdd-156             [-1, 197, 768]               0
#        LayerNorm-157             [-1, 197, 768]           1,536
#           Linear-158            [-1, 197, 3072]       2,362,368
#             GELU-159            [-1, 197, 3072]               0
#          Dropout-160            [-1, 197, 3072]               0
#           Linear-161             [-1, 197, 768]       2,360,064
#          Dropout-162             [-1, 197, 768]               0
#      ResidualAdd-163             [-1, 197, 768]               0
#        LayerNorm-164             [-1, 197, 768]           1,536
#           Linear-165             [-1, 197, 768]         590,592
#           Linear-166             [-1, 197, 768]         590,592
#           Linear-167             [-1, 197, 768]         590,592
#          Dropout-168          [-1, 8, 197, 197]               0
#           Linear-169             [-1, 197, 768]         590,592
# MultiHeadAttention-170             [-1, 197, 768]               0
#          Dropout-171             [-1, 197, 768]               0
#      ResidualAdd-172             [-1, 197, 768]               0
#        LayerNorm-173             [-1, 197, 768]           1,536
#           Linear-174            [-1, 197, 3072]       2,362,368
#             GELU-175            [-1, 197, 3072]               0
#          Dropout-176            [-1, 197, 3072]               0
#           Linear-177             [-1, 197, 768]       2,360,064
#          Dropout-178             [-1, 197, 768]               0
#      ResidualAdd-179             [-1, 197, 768]               0
#        LayerNorm-180             [-1, 197, 768]           1,536
#           Linear-181             [-1, 197, 768]         590,592
#           Linear-182             [-1, 197, 768]         590,592
#           Linear-183             [-1, 197, 768]         590,592
#          Dropout-184          [-1, 8, 197, 197]               0
#           Linear-185             [-1, 197, 768]         590,592
# MultiHeadAttention-186             [-1, 197, 768]               0
#          Dropout-187             [-1, 197, 768]               0
#      ResidualAdd-188             [-1, 197, 768]               0
#        LayerNorm-189             [-1, 197, 768]           1,536
#           Linear-190            [-1, 197, 3072]       2,362,368
#             GELU-191            [-1, 197, 3072]               0
#          Dropout-192            [-1, 197, 3072]               0
#           Linear-193             [-1, 197, 768]       2,360,064
#          Dropout-194             [-1, 197, 768]               0
#      ResidualAdd-195             [-1, 197, 768]               0
#           Reduce-196                  [-1, 768]               0
#        LayerNorm-197                  [-1, 768]           1,536
#           Linear-198                   [-1, 10]           7,690
# ================================================================
# Total params: 85,654,282
# Trainable params: 85,654,282
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 364.33
# Params size (MB): 326.75
# Estimated Total Size (MB): 691.64
# ----------------------------------------------------------------

# %%
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

# %%
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()

    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b

        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric

# %%
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
params_train = {
    'num_epochs':100,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# check the directory to save weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr= 0.01
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Copied best model weights!
# train loss: 3.228899, val loss: 2.277369, accuracy: 16.07, time: 1.9527 min
# ----------
# Epoch 1/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.204332, val loss: 2.099537, accuracy: 17.96, time: 3.9168 min
# ----------
# Epoch 2/99, current lr= 0.01
# train loss: 2.126980, val loss: 2.125568, accuracy: 13.89, time: 5.7721 min
# ----------
# Epoch 3/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.050376, val loss: 2.080815, accuracy: 17.46, time: 7.7105 min
# ----------
# Epoch 4/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.021238, val loss: 2.024345, accuracy: 19.32, time: 9.6706 min
# ----------
# Epoch 5/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.014259, val loss: 1.954741, accuracy: 24.24, time: 11.6144 min
# ----------
# Epoch 6/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.922393, val loss: 1.879200, accuracy: 25.80, time: 13.5271 min
# ----------
# Epoch 7/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.912131, val loss: 1.876987, accuracy: 26.67, time: 15.4858 min
# ----------
# Epoch 8/99, current lr= 0.01
# train loss: 1.935599, val loss: 1.898281, accuracy: 25.65, time: 17.3294 min
# ----------
# Epoch 9/99, current lr= 0.01
# train loss: 1.887685, val loss: 1.889637, accuracy: 25.85, time: 19.1712 min
# ----------
# Epoch 10/99, current lr= 0.01
# train loss: 1.873043, val loss: 1.914850, accuracy: 23.77, time: 21.0385 min
# ----------
# Epoch 11/99, current lr= 0.01
# train loss: 1.872136, val loss: 1.893199, accuracy: 25.62, time: 22.8929 min
# ----------
# Epoch 12/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.874266, val loss: 1.849845, accuracy: 28.46, time: 24.8466 min
# ----------
# Epoch 13/99, current lr= 0.01
# train loss: 1.881790, val loss: 1.939681, accuracy: 25.81, time: 26.7144 min
# ----------
# Epoch 14/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.856533, val loss: 1.835624, accuracy: 28.18, time: 28.6580 min
# ----------
# Epoch 15/99, current lr= 0.01
# train loss: 1.870354, val loss: 1.877351, accuracy: 24.06, time: 30.5004 min
# ----------
# Epoch 16/99, current lr= 0.01
# train loss: 1.859412, val loss: 1.865423, accuracy: 27.24, time: 32.3653 min
# ----------
# Epoch 17/99, current lr= 0.01
# train loss: 1.865509, val loss: 1.853006, accuracy: 28.18, time: 34.2155 min
# ----------
# Epoch 18/99, current lr= 0.01
# train loss: 1.874901, val loss: 1.847291, accuracy: 29.28, time: 36.0778 min
# ----------
# Epoch 19/99, current lr= 0.01
# train loss: 1.906487, val loss: 1.927572, accuracy: 23.62, time: 37.9498 min
# ----------
# Epoch 20/99, current lr= 0.01
# train loss: 1.962984, val loss: 2.059866, accuracy: 17.97, time: 39.7999 min
# ----------
# Epoch 21/99, current lr= 0.01
# train loss: 1.941863, val loss: 1.961862, accuracy: 23.46, time: 41.6443 min
# ----------
# Epoch 22/99, current lr= 0.01
# train loss: 1.945869, val loss: 1.931996, accuracy: 25.31, time: 43.4986 min
# ----------
# Epoch 23/99, current lr= 0.01
# train loss: 1.907560, val loss: 1.999919, accuracy: 22.50, time: 45.3563 min
# ----------
# Epoch 24/99, current lr= 0.01
# train loss: 1.903451, val loss: 1.886238, accuracy: 26.49, time: 47.1941 min
# ----------
# Epoch 25/99, current lr= 0.01
# Loading best model weights!
# train loss: 1.896821, val loss: 1.895569, accuracy: 26.56, time: 49.0479 min
# ----------
# Epoch 26/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.797821, val loss: 1.803808, accuracy: 29.66, time: 50.9828 min
# ----------
# Epoch 27/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.784794, val loss: 1.784115, accuracy: 31.29, time: 52.9281 min
# ----------
# Epoch 28/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.778073, val loss: 1.782727, accuracy: 30.98, time: 54.8819 min
# ----------
# Epoch 29/99, current lr= 0.001
# train loss: 1.774210, val loss: 1.783578, accuracy: 31.25, time: 56.7483 min
# ----------
# Epoch 30/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.766607, val loss: 1.776185, accuracy: 31.35, time: 58.6922 min
# ----------
# Epoch 31/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.762001, val loss: 1.770971, accuracy: 31.40, time: 60.6328 min
# ----------
# Epoch 32/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.759222, val loss: 1.769345, accuracy: 31.51, time: 62.5275 min
# ----------
# Epoch 33/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.752399, val loss: 1.759968, accuracy: 32.35, time: 64.4825 min
# ----------
# Epoch 34/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.744857, val loss: 1.751368, accuracy: 31.89, time: 66.4415 min
# ----------
# Epoch 35/99, current lr= 0.001
# train loss: 1.737619, val loss: 1.758675, accuracy: 32.29, time: 68.3048 min
# ----------
# Epoch 36/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.730119, val loss: 1.744754, accuracy: 32.11, time: 70.2640 min
# ----------
# Epoch 37/99, current lr= 0.001
# train loss: 1.795294, val loss: 1.789096, accuracy: 30.89, time: 72.1137 min
# ----------
# Epoch 38/99, current lr= 0.001
# train loss: 1.765720, val loss: 1.774841, accuracy: 31.51, time: 73.9900 min
# ----------
# Epoch 39/99, current lr= 0.001
# train loss: 1.758568, val loss: 1.781847, accuracy: 31.55, time: 75.8361 min
# ----------
# Epoch 40/99, current lr= 0.001
# train loss: 1.755004, val loss: 1.757302, accuracy: 31.86, time: 77.6864 min
# ----------
# Epoch 41/99, current lr= 0.001
# train loss: 1.740479, val loss: 1.749134, accuracy: 32.20, time: 79.5416 min
# ----------
# Epoch 42/99, current lr= 0.001
# train loss: 1.733123, val loss: 1.760621, accuracy: 32.25, time: 81.3919 min
# ----------
# Epoch 43/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.709546, val loss: 1.733599, accuracy: 32.46, time: 83.3347 min
# ----------
# Epoch 44/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.695371, val loss: 1.720106, accuracy: 33.65, time: 85.2825 min
# ----------
# Epoch 45/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.690685, val loss: 1.719391, accuracy: 33.64, time: 87.2422 min
# ----------
# Epoch 46/99, current lr= 0.001
# train loss: 1.682200, val loss: 1.720915, accuracy: 32.99, time: 89.0914 min
# ----------
# Epoch 47/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.695964, val loss: 1.711151, accuracy: 33.34, time: 90.9819 min
# ----------
# Epoch 48/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.685779, val loss: 1.709904, accuracy: 33.95, time: 92.9386 min
# ----------
# Epoch 49/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.672071, val loss: 1.699242, accuracy: 34.23, time: 94.8862 min
# ----------
# Epoch 50/99, current lr= 0.001
# train loss: 1.661325, val loss: 1.712939, accuracy: 34.26, time: 96.7428 min
# ----------
# Epoch 51/99, current lr= 0.001
# train loss: 1.664714, val loss: 1.700618, accuracy: 34.23, time: 98.6059 min
# ----------
# Epoch 52/99, current lr= 0.001
# train loss: 1.660458, val loss: 1.703069, accuracy: 34.01, time: 100.4525 min
# ----------
# Epoch 53/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.652980, val loss: 1.690722, accuracy: 34.65, time: 102.4068 min
# ----------
# Epoch 54/99, current lr= 0.001
# train loss: 1.652802, val loss: 1.704680, accuracy: 33.98, time: 104.2825 min
# ----------
# Epoch 55/99, current lr= 0.001
# train loss: 1.707917, val loss: 1.716241, accuracy: 32.80, time: 106.1392 min
# ----------
# Epoch 56/99, current lr= 0.001
# train loss: 1.670518, val loss: 1.702443, accuracy: 33.96, time: 108.0004 min
# ----------
# Epoch 57/99, current lr= 0.001
# train loss: 1.654765, val loss: 1.694960, accuracy: 33.99, time: 109.8561 min
# ----------
# Epoch 58/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.660840, val loss: 1.690652, accuracy: 34.50, time: 111.8144 min
# ----------
# Epoch 59/99, current lr= 0.001
# train loss: 1.674723, val loss: 1.700496, accuracy: 33.64, time: 113.6647 min
# ----------
# Epoch 60/99, current lr= 0.001
# train loss: 1.646790, val loss: 1.695085, accuracy: 34.42, time: 115.5309 min
# ----------
# Epoch 61/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.638219, val loss: 1.679785, accuracy: 34.79, time: 117.5060 min
# ----------
# Epoch 62/99, current lr= 0.001
# train loss: 1.634100, val loss: 1.685031, accuracy: 34.71, time: 119.3661 min
# ----------
# Epoch 63/99, current lr= 0.001
# train loss: 1.639125, val loss: 1.681543, accuracy: 35.01, time: 121.2245 min
# ----------
# Epoch 64/99, current lr= 0.001
# train loss: 1.636021, val loss: 1.688205, accuracy: 34.20, time: 123.0843 min
# ----------
# Epoch 65/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.633586, val loss: 1.679133, accuracy: 34.14, time: 125.0675 min
# ----------
# Epoch 66/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.637875, val loss: 1.678847, accuracy: 35.43, time: 127.0272 min
# ----------
# Epoch 67/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.624503, val loss: 1.672673, accuracy: 35.14, time: 129.0154 min
# ----------
# Epoch 68/99, current lr= 0.001
# train loss: 1.621886, val loss: 1.732601, accuracy: 31.87, time: 130.8981 min
# ----------
# Epoch 69/99, current lr= 0.001
# train loss: 1.672963, val loss: 1.749553, accuracy: 32.34, time: 132.7598 min
# ----------
# Epoch 70/99, current lr= 0.001
# train loss: 1.659284, val loss: 1.682054, accuracy: 34.76, time: 134.6220 min
# ----------
# Epoch 71/99, current lr= 0.001
# train loss: 1.618980, val loss: 1.676154, accuracy: 35.35, time: 136.4952 min
# ----------
# Epoch 72/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.615544, val loss: 1.656490, accuracy: 36.00, time: 138.4588 min
# ----------
# Epoch 73/99, current lr= 0.001
# train loss: 1.623490, val loss: 1.685501, accuracy: 34.88, time: 140.3159 min
# ----------
# Epoch 74/99, current lr= 0.001
# train loss: 1.674359, val loss: 1.709027, accuracy: 33.96, time: 142.1748 min
# ----------
# Epoch 75/99, current lr= 0.001
# train loss: 1.830411, val loss: 1.869412, accuracy: 28.71, time: 144.0371 min
# ----------
# Epoch 76/99, current lr= 0.001
# train loss: 1.760596, val loss: 1.753508, accuracy: 32.59, time: 145.8959 min
# ----------
# Epoch 77/99, current lr= 0.001
# train loss: 1.727766, val loss: 1.765232, accuracy: 31.29, time: 147.7480 min
# ----------
# Epoch 78/99, current lr= 0.001
# train loss: 1.717281, val loss: 1.707868, accuracy: 33.59, time: 149.6218 min
# ----------
# Epoch 79/99, current lr= 0.001
# train loss: 1.728324, val loss: 1.837389, accuracy: 30.43, time: 151.4710 min
# ----------
# Epoch 80/99, current lr= 0.001
# train loss: 1.760205, val loss: 1.721098, accuracy: 33.45, time: 153.3325 min
# ----------
# Epoch 81/99, current lr= 0.001
# train loss: 1.688114, val loss: 1.681451, accuracy: 35.11, time: 155.1866 min
# ----------
# Epoch 82/99, current lr= 0.001
# train loss: 1.678750, val loss: 1.682770, accuracy: 34.86, time: 157.0554 min
# ----------
# Epoch 83/99, current lr= 0.001
# Loading best model weights!
# train loss: 1.682920, val loss: 1.729506, accuracy: 33.39, time: 158.9108 min
# ----------
# Epoch 84/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.588274, val loss: 1.650267, accuracy: 36.38, time: 160.8797 min
# ----------
# Epoch 85/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.582435, val loss: 1.648677, accuracy: 36.10, time: 162.8405 min
# ----------
# Epoch 86/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.579862, val loss: 1.648428, accuracy: 36.21, time: 164.8059 min
# ----------
# Epoch 87/99, current lr= 0.0001
# train loss: 1.577984, val loss: 1.648888, accuracy: 36.25, time: 166.6664 min
# ----------
# Epoch 88/99, current lr= 0.0001
# train loss: 1.576846, val loss: 1.648530, accuracy: 36.05, time: 168.5183 min
# ----------
# Epoch 89/99, current lr= 0.0001
# train loss: 1.575533, val loss: 1.649386, accuracy: 36.36, time: 170.4039 min
# ----------
# Epoch 90/99, current lr= 0.0001
# train loss: 1.574153, val loss: 1.649387, accuracy: 36.09, time: 172.2587 min
# ----------
# Epoch 91/99, current lr= 0.0001
# train loss: 1.573265, val loss: 1.649335, accuracy: 36.08, time: 174.1223 min
# ----------
# Epoch 92/99, current lr= 0.0001
# train loss: 1.573134, val loss: 1.649619, accuracy: 36.36, time: 175.9739 min
# ----------
# Epoch 93/99, current lr= 0.0001
# train loss: 1.571779, val loss: 1.648704, accuracy: 36.05, time: 177.8431 min
# ----------
# Epoch 94/99, current lr= 0.0001
# train loss: 1.572261, val loss: 1.656876, accuracy: 35.91, time: 179.6919 min
# ----------
# Epoch 95/99, current lr= 0.0001
# train loss: 1.577621, val loss: 1.652095, accuracy: 36.38, time: 181.5488 min
# ----------
# Epoch 96/99, current lr= 0.0001
# train loss: 1.579447, val loss: 1.701225, accuracy: 35.38, time: 183.4034 min
# ----------
# Epoch 97/99, current lr= 0.0001
# Loading best model weights!
# train loss: 1.590266, val loss: 1.654312, accuracy: 36.40, time: 185.2771 min
# ----------
# Epoch 98/99, current lr= 1e-05
# train loss: 1.576808, val loss: 1.648456, accuracy: 36.27, time: 187.1343 min
# ----------
# Epoch 99/99, current lr= 1e-05
# train loss: 1.576540, val loss: 1.648555, accuracy: 36.21, time: 188.9817 min
# ----------

# %%
num_epochs = params_train['num_epochs']

# Plot train-val loss
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot train-val accuracy
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()
